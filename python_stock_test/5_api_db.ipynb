# %%
import matplotlib.pyplot as plt
from Investar import Analyzer

mk = Analyzer.MarketDB()
df = mk.get_daily_price('005930', '2017-07-10', '2018-06-30')

plt.figure(figsize=(9,6))
plt.subplot(2,1,1)
plt.title('samsung electronics (Investar Data)')
plt.plot(df.index, df['close'], 'c', label='Close')
plt.legend(loc="best")
plt.subplot(2,1,2)
plt.bar(df.index, df['volume'], color='g', label='Volume')
plt.legend(loc='best')
plt.show()

# %%
import pymysql

connection = pymysql.connect(host='18.222.188.155', port=3306, db='investar', user='root', passwd='Tftfat024!!', autocommit=True)

cursor = connection.cursor()
cursor.execute('select version();')
result = cursor.fetchone()

print('Maria db version : {}'.format(result))
connection.close()
# Out:
# Maria db version : ('10.3.29-MariaDB-0ubuntu0.20.04.1',)

# %%
# 배치 파일 자동실행 하게 하기
# DBUpdaer 배치 파일
# 메모장을 이용해 DBUpdater배치 파일 만들기
# 메모장 안에 python C://경로/DBUpdater.py

# 윈도우 + R키를 클릭 하여 실행 창을 띄운후 regedit를 입력 하여 레지리스트 편집기 실행
# hkey_local_machine\software\microsoft\windows\currentversion\run 키를 우릌ㄹ릭 하여
# 새로 만들기 메뉴 클릭 후 dbupdate라는 문자열 값으로 C://경로/DBUpdater.bat 지정

# %%
import
