# %%
import pandas as pd

# %%
krx_list = pd.read_html('C:\dev\python-stock/상장법인목록.xls')
krx_list[0]
# Out:
#            회사명    종목코드                        업종  \
# 0         엘비루셈  376190                   반도체 제조업
# 1       이성씨엔아이  379390  건축기술, 엔지니어링 및 관련 기술 서비스업
# 2      에이디엠코리아  187660           자연과학 및 공학 연구개발업
# 3     에코프로에이치엔  383310               기타 화학제품 제조업
# 4        LX홀딩스  383800                    기타 금융업
# ...        ...     ...                       ...
# 2443    CJ대한통운     120                 도로 화물 운송업
# 2444     메리츠화재      60                       보험업
# 2445        경방      50                    종합 소매업
# 2446     유수홀딩스     700       회사 본부 및 경영 컨설팅 서비스업
# 2447  한진중공업홀딩스    3480         연료용 가스 제조 및 배관공급업
#
#                                                    주요제품         상장일  결산월  \
# 0                               디스플레이 구동 반도체(Driver IC)  2021-06-11  12월
# 1                                 원자력발전소 계측제어 서비스(경상정비)  2021-06-04  12월
# 2                                            임상 CRO 서비스  2021-06-03  12월
# 3                                    환경오염 방지 관련 소재 및 설비  2021-05-28  12월
# ...

# %%
# 여섯자리 숫자형식으로 표현 하되 앞자리를 0으로 채우기
krx_list[0].종목코드 = krx_list[0].종목코드.map('{:06d}'.format) 
krx_list[0]
# Out:
#            회사명    종목코드                        업종  \
# 0         엘비루셈  376190                   반도체 제조업
# 1       이성씨엔아이  379390  건축기술, 엔지니어링 및 관련 기술 서비스업
# 2      에이디엠코리아  187660           자연과학 및 공학 연구개발업
# 3     에코프로에이치엔  383310               기타 화학제품 제조업
# 4        LX홀딩스  383800                    기타 금융업
# ...        ...     ...                       ...
# 2443    CJ대한통운  000120                 도로 화물 운송업
# 2444     메리츠화재  000060                       보험업
# 2445        경방  000050                    종합 소매업
# 2446     유수홀딩스  000700       회사 본부 및 경영 컨설팅 서비스업
# 2447  한진중공업홀딩스  003480         연료용 가스 제조 및 배관공급업
#
#                                                    주요제품         상장일  결산월  \
# 0                               디스플레이 구동 반도체(Driver IC)  2021-06-11  12월
# 1                                 원자력발전소 계측제어 서비스(경상정비)  2021-06-04  12월
# 2                                            임상 CRO 서비스  2021-06-03  12월
# 3                                    환경오염 방지 관련 소재 및 설비  2021-05-28  12월
# ...
